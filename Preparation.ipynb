# %%
# !pip install pandas
# !pip install sklearn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

file = pd.read_csv("combats.partial.csv")
train, test = train_test_split( file, test_size = 0.3, random_state = 0)
train.to_csv("train.csv", index=False)
test.to_csv("test.csv", index=False)
